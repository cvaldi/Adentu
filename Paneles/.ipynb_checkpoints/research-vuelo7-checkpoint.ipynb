# %%
import cv2
import tifffile as tiff
import exifread 
import matplotlib.pyplot as pl
import numpy as np
import os
from __future__ import division

pts_origin = [  [279,30],
                [409,33],
                [130,750],
                [246,796],
                [649,110],
                [798,117],
                [498,832],
                [632,873],
                [1015,193],
                [1182,202],
                [860,913],
                [1013,959]]

pts_target = [  [175,66],
                [216,67],
                [125,298],
                [161,311],
                [292,92],
                [339,94],
                [241,324],
                [284,338],
                [408,118],
                [461,123],
                [358,351],
                [405,365]]

pts_origin = np.array(pts_origin).astype(float)
pts_target = np.array(pts_target).astype(float)

H = cv2.findHomography(pts_origin, pts_target)

# %%
# ejemplo para obtener homografía
img_dir = '/home/ivan/Documents/Adentu/DATA/Paneles/Vuelos/Vuelo_17_38m-7ms-SF72-SL80-GSD5_(1de4)/Imagenes'
# IRGB = cv2.cvtColor(cv2.imread(os.path.join(img_dir,'09-17-03-738_digital.jpg')), cv2.COLOR_BGR2RGB)
# ITERM = tiff.imread(os.path.join(img_dir, '09-17-03-752_radiometric.tiff')).astype(float)

RGBlist = sorted([o for o in os.listdir(img_dir) if 'digital.jpg' in o])
RAWlist = sorted([o for o in os.listdir(img_dir) if 'radiometric.tiff' in o])

print len(RGBlist)
base_height = None

for imrgb, imtiff in zip(RGBlist, RAWlist):
    if base_height is None:
        exif = exifread.process_file(open(os.path.join(img_dir,imrgb),'rb'))
        height = eval(str(exif['GPS GPSAltitude']))
        base_height = height
        
#     if '09-08-14-664_digital.jpg' not in imrgb:
#         continue    
    IRGB = cv2.cvtColor(cv2.imread(os.path.join(img_dir,imrgb)), cv2.COLOR_BGR2RGB)
    ITERM = tiff.imread(os.path.join(img_dir, imtiff)).astype(float)
    
    #print ITERM.min(), ITERM.max()

    exif = exifread.process_file(open(os.path.join(img_dir,imrgb),'rb'))
    
    height = eval(str(exif['GPS GPSAltitude']))
    
    if base_height is None:
        base_height = height
    
    #print height - base_height
    
    if height - base_height < 28:
        continue
    
    print imrgb, imtiff
    
    ITERM = ((ITERM - ITERM.min())/(ITERM.max()-ITERM.min())*255).astype(np.uint8)

    I2 = cv2.warpPerspective(IRGB, H[0], ITERM.shape[::-1], flags=cv2.INTER_AREA)
    
#     pl.figure(figsize=(6,6))
#     pl.imshow(ITERM, cmap='gray')
#     pl.show()
    
    ERGB = cv2.Canny(I2, 250, 350)
    ERGB[np.where(cv2.dilate((I2[:,:,0]==0).astype(np.uint8)*255, np.ones((10,10))))] = 0
    ERGB = ERGB[80:-80, 80:-80]
    
    ERGB = cv2.dilate(ERGB, np.ones((5,5)))
    #ERGB = cv2.GaussianBlur(ERGB, (11,11),2)
    
#     pl.figure(figsize=(6,6))
#     pl.imshow(ERGB, cmap='gray')
#     pl.show()

    ETERM = cv2.Canny(ITERM, 10, 140)
    ETERM = cv2.dilate(ETERM, np.ones((5,5)))
    #ETERM = cv2.GaussianBlur(ETERM, (11,11),2)
    #ETERM[np.where(cv2.dilate((I2[:,:,0]==0).astype(np.uint8)*255, np.ones((10,10))))] = 0

#     pl.figure(figsize=(6,6))
#     pl.imshow(ETERM, cmap='gray')
#     pl.show()

    res = cv2.matchTemplate(ERGB, ETERM, cv2.TM_CCOEFF_NORMED)

#     pl.figure(figsize=(12,12))
#     pl.imshow(res)
#     pl.show()

    a = res.argmax()

    xd = a%res.shape[0] - 80
    yd = a//res.shape[0] - 80

    #print xd, yd

    H2 = np.array([[1,0,xd],[0,1,yd],[0,0,1]]).astype(np.float)
    I3 = cv2.warpPerspective(I2, H2, (I2.shape[1], I2.shape[0]), flags=cv2.INTER_AREA)

#     pl.figure(figsize=(6,6))
#     pl.imshow(I3)
#     pl.show()
    
    I2LAB = cv2.cvtColor(I3, cv2.COLOR_RGB2LAB)
    #I2LAB = I3
    
#     pl.figure(figsize=(12,6))
#     pl.imshow(np.concatenate((I3[:,:,0],I3[:,:,1],I3[:,:,2]), axis=1), cmap='gray')
#     pl.show()

#   IMASK = (I2LAB[:,:,2]<110) * (I2LAB[:,:,0]>60) * (I2LAB[:,:,0]<160) * (ITERM > 100)
    IMASK = (I2LAB[:,:,2]<110) * (I2LAB[:,:,0]>40) * (I2LAB[:,:,0]<160) * (ITERM > 100) * (I3[:,:,2] > I3[:,:,0]+30)

    #IMASK2 = cv2.erode(cv2.dilate(IMASK.astype(np.uint8), np.ones((10,10))), np.ones((10,10)))
    pl.figure(figsize=(6,6))
    pl.imshow(IMASK*ITERM)
    pl.show()
# Out:
# 1283
# 09-04-27-581_digital.jpg 09-04-27-583_radiometric.tiff
# 09-04-28-599_digital.jpg 09-04-28-600_radiometric.tiff
# 09-04-29-596_digital.jpg 09-04-29-599_radiometric.tiff
# 09-04-30-618_digital.jpg 09-04-30-620_radiometric.tiff
# 09-04-31-622_digital.jpg 09-04-31-624_radiometric.tiff
# 09-04-32-684_digital.jpg 09-04-32-685_radiometric.tiff
# 09-04-33-679_digital.jpg 09-04-33-681_radiometric.tiff
# 09-04-34-724_digital.jpg 09-04-34-726_radiometric.tiff
# 09-04-35-650_digital.jpg 09-04-35-653_radiometric.tiff
# 09-04-36-781_digital.jpg 09-04-36-784_radiometric.tiff
# 09-04-37-746_digital.jpg 09-04-37-748_radiometric.tiff
# 09-04-38-663_digital.jpg 09-04-38-664_radiometric.tiff
# 09-04-39-645_digital.jpg 09-04-39-646_radiometric.tiff
# 09-04-40-596_digital.jpg 09-04-40-598_radiometric.tiff
# 09-04-41-679_digital.jpg 09-04-41-680_radiometric.tiff
# 09-04-42-662_digital.jpg 09-04-42-664_radiometric.tiff
# 09-04-43-685_digital.jpg 09-04-43-687_radiometric.tiff
# 09-04-44-655_digital.jpg 09-04-44-657_radiometric.tiff
# 09-04-45-652_digital.jpg 09-04-45-654_radiometric.tiff
# 09-04-46-626_digital.jpg 09-04-46-636_radiometric.tiff
# 09-04-47-689_digital.jpg 09-04-47-691_radiometric.tiff
# 09-04-48-710_digital.jpg 09-04-48-713_radiometric.tiff
# 09-04-49-690_digital.jpg 09-04-49-692_radiometric.tiff
# 09-04-50-659_digital.jpg 09-04-50-661_radiometric.tiff
# 09-04-51-672_digital.jpg 09-04-51-674_radiometric.tiff
# 09-04-52-662_digital.jpg 09-04-52-664_radiometric.tiff
# 09-04-53-651_digital.jpg 09-04-53-653_radiometric.tiff
# 09-04-54-644_digital.jpg 09-04-54-646_radiometric.tiff
# 09-04-55-661_digital.jpg 09-04-55-663_radiometric.tiff
# 09-04-56-660_digital.jpg 09-04-56-661_radiometric.tiff
# 09-04-57-646_digital.jpg 09-04-57-649_radiometric.tiff
# 09-04-58-649_digital.jpg 09-04-58-651_radiometric.tiff
# 09-04-59-653_digital.jpg 09-04-59-656_radiometric.tiff
# 09-05-00-678_digital.jpg 09-05-00-680_radiometric.tiff
# 09-05-01-682_digital.jpg 09-05-01-684_radiometric.tiff
# 09-05-02-688_digital.jpg 09-05-02-690_radiometric.tiff
# 09-05-03-681_digital.jpg 09-05-03-683_radiometric.tiff
# 09-05-04-689_digital.jpg 09-05-04-691_radiometric.tiff
# 09-05-05-710_digital.jpg 09-05-05-712_radiometric.tiff
# 09-05-06-761_digital.jpg 09-05-06-763_radiometric.tiff
# 09-05-07-713_digital.jpg 09-05-07-716_radiometric.tiff
# 09-05-08-747_digital.jpg 09-05-08-750_radiometric.tiff
# 09-05-09-732_digital.jpg 09-05-09-736_radiometric.tiff
# 09-05-10-700_digital.jpg 09-05-10-703_radiometric.tiff
# 09-05-11-697_digital.jpg 09-05-11-700_radiometric.tiff
# 09-05-12-699_digital.jpg 09-05-12-702_radiometric.tiff
# 09-05-13-736_digital.jpg 09-05-13-739_radiometric.tiff
# 09-05-14-666_digital.jpg 09-05-14-669_radiometric.tiff
# 09-05-15-737_digital.jpg 09-05-15-742_radiometric.tiff
# 09-05-16-727_digital.jpg 09-05-16-731_radiometric.tiff
# 09-05-17-696_digital.jpg 09-05-17-698_radiometric.tiff
# 09-05-18-747_digital.jpg 09-05-18-750_radiometric.tiff
# 09-05-19-686_digital.jpg 09-05-19-689_radiometric.tiff
# 09-05-20-760_digital.jpg 09-05-20-762_radiometric.tiff
# 09-05-21-701_digital.jpg 09-05-21-709_radiometric.tiff
# 09-05-22-760_digital.jpg 09-05-22-762_radiometric.tiff
# 09-05-23-749_digital.jpg 09-05-23-752_radiometric.tiff
# 09-05-24-716_digital.jpg 09-05-24-720_radiometric.tiff
# 09-05-25-649_digital.jpg 09-05-25-652_radiometric.tiff
# 09-05-26-652_digital.jpg 09-05-26-655_radiometric.tiff
# 09-05-27-601_digital.jpg 09-05-27-604_radiometric.tiff
# 09-05-28-656_digital.jpg 09-05-28-659_radiometric.tiff
# 09-05-29-600_digital.jpg 09-05-29-602_radiometric.tiff
# 09-05-30-642_digital.jpg 09-05-30-645_radiometric.tiff
# 09-05-31-681_digital.jpg 09-05-31-684_radiometric.tiff
# 09-05-32-630_digital.jpg 09-05-32-634_radiometric.tiff
# 09-05-33-647_digital.jpg 09-05-33-650_radiometric.tiff
# 09-05-34-662_digital.jpg 09-05-34-664_radiometric.tiff
# 09-05-35-723_digital.jpg 09-05-35-727_radiometric.tiff
# 09-05-36-749_digital.jpg 09-05-36-752_radiometric.tiff
# 09-05-37-645_digital.jpg 09-05-37-648_radiometric.tiff
# 09-05-38-661_digital.jpg 09-05-38-664_radiometric.tiff
# 09-05-39-648_digital.jpg 09-05-39-652_radiometric.tiff
# 09-05-40-681_digital.jpg 09-05-40-683_radiometric.tiff
# 09-05-41-630_digital.jpg 09-05-41-633_radiometric.tiff
# 09-05-42-626_digital.jpg 09-05-42-629_radiometric.tiff
# 09-05-43-624_digital.jpg 09-05-43-626_radiometric.tiff
# 09-05-44-652_digital.jpg 09-05-44-655_radiometric.tiff
# 09-05-45-670_digital.jpg 09-05-45-673_radiometric.tiff
# 09-05-46-672_digital.jpg 09-05-46-675_radiometric.tiff
# 09-05-47-680_digital.jpg 09-05-47-683_radiometric.tiff
# 09-05-48-677_digital.jpg 09-05-48-680_radiometric.tiff
# 09-05-49-704_digital.jpg 09-05-49-709_radiometric.tiff
# 09-05-50-725_digital.jpg 09-05-50-729_radiometric.tiff
# 09-05-51-740_digital.jpg 09-05-51-742_radiometric.tiff
# 09-05-52-725_digital.jpg 09-05-52-728_radiometric.tiff
# 09-05-53-622_digital.jpg 09-05-53-625_radiometric.tiff
# 09-05-54-584_digital.jpg 09-05-54-586_radiometric.tiff
# 09-05-55-654_digital.jpg 09-05-55-657_radiometric.tiff
# 09-05-56-637_digital.jpg 09-05-56-640_radiometric.tiff
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7c63899d45f2> in <module>()
#      97     #IMASK2 = cv2.erode(cv2.dilate(IMASK.astype(np.uint8), np.ones((10,10))), np.ones((10,10)))
#      98     pl.figure(figsize=(6,6))
# ---> 99     pl.imshow(IMASK*ITERM)
#     100     pl.show()
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3008            filternorm=1, filterrad=4.0, imlim=None, resample=None, url=None,
#    3009            hold=None, data=None, **kwargs):
# -> 3010     ax = gca()
#    3011     # allow callers to override the hold state by passing hold=True|False
#    3012     washold = ax.ishold()
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in gca(**kwargs)
#     926     matplotlib.figure.Figure.gca : The figure's gca method.
#     927     """
# --> 928     return gcf().gca(**kwargs)
#     929
#     930 # More ways of creating axes:
#
# /usr/lib/python2.7/dist-packages/matplotlib/figure.pyc in gca(self, **kwargs)
#    1357
#    1358         # no axes found, so create one which spans the figure
# -> 1359         return self.add_subplot(1, 1, 1, **kwargs)
#    1360
#    1361     def sca(self, a):
#
# /usr/lib/python2.7/dist-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1003                     self._axstack.remove(ax)
#    1004
# -> 1005             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1006
#    1007         self._axstack.add(key, a)
#
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     518         self._hold = rcParams['axes.hold']
#     519         self._connected = {}  # a dict from events to (id, func)
# --> 520         self.cla()
#     521         # funcs used to format x and y - fall back on major formatters
#     522         self.fmt_xdata = None
#
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in cla(self)
#     919         self.yaxis.cla()
#     920         for name, spine in six.iteritems(self.spines):
# --> 921             spine.cla()
#     922
#     923         self.ignore_existing_data_limits = True
#
# /usr/lib/python2.7/dist-packages/matplotlib/spines.pyc in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /usr/lib/python2.7/dist-packages/matplotlib/axis.pyc in cla(self)
#     740         self._set_artist_props(self.label)
#     741
# --> 742         self.reset_ticks()
#     743
#     744         self.converter = None
#
# /usr/lib/python2.7/dist-packages/matplotlib/axis.pyc in reset_ticks(self)
#     755
#     756         self.majorTicks.extend([self._get_tick(major=True)])
# --> 757         self.minorTicks.extend([self._get_tick(major=False)])
#     758         self._lastNumMajorTicks = 1
#     759         self._lastNumMinorTicks = 1
#
# /usr/lib/python2.7/dist-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1673         else:
#    1674             tick_kw = self._minor_tick_kw
# -> 1675         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1676
#    1677     def _get_label(self):
#
# /usr/lib/python2.7/dist-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     149
#     150         self.tick1line = self._get_tick1line()
# --> 151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#     153
#
# /usr/lib/python2.7/dist-packages/matplotlib/axis.pyc in _get_tick2line(self)
#     412                           markersize=self._size,
#     413                           markeredgewidth=self._width,
# --> 414                           zorder=self._zorder)
#     415
#     416         l.set_transform(self.axes.get_xaxis_transform(which='tick2'))
#
# /usr/lib/python2.7/dist-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     336         self._color = None
#     337         self.set_color(color)
# --> 338         self._marker = MarkerStyle()
#     339         self.set_marker(marker)
#     340
#
# /usr/lib/python2.7/dist-packages/matplotlib/markers.pyc in __init__(self, marker, fillstyle)
#     169         # _recache() in set_marker.
#     170         self._fillstyle = fillstyle
# --> 171         self.set_marker(marker)
#     172         self.set_fillstyle(fillstyle)
#     173
#
# /usr/lib/python2.7/dist-packages/matplotlib/markers.pyc in set_marker(self, marker)
#     253
#     254         self._marker = marker
# --> 255         self._recache()
#     256
#     257     def get_path(self):
#
# /usr/lib/python2.7/dist-packages/matplotlib/markers.pyc in _recache(self)
#     183
#     184     def _recache(self):
# --> 185         self._path = Path(np.empty((0, 2)))
#     186         self._transform = IdentityTransform()
#     187         self._alt_path = None
#
# /usr/lib/python2.7/dist-packages/matplotlib/path.pyc in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     160         self._codes = codes
#     161         self._interpolation_steps = _interpolation_steps
# --> 162         self._update_values()
#     163
#     164         if readonly:
#
# /usr/lib/python2.7/dist-packages/matplotlib/path.pyc in _update_values(self)
#     217         )
#     218         self._simplify_threshold = rcParams['path.simplify_threshold']
# --> 219         self._has_nonfinite = not np.isfinite(self._vertices).all()
#     220
#     221     @property
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.pyc in _all(a, axis, dtype, out, keepdims)
#      39
#      40 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 41     return umr_all(a, axis, dtype, out, keepdims)
#      42
#      43 def _count_reduce_items(arr, axis):
#
# KeyboardInterrupt:

# %%
cv2.GaussianBlur?
